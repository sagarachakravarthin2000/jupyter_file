# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The wanted tools need to be imported

# %%
df = pd.read_csv("car_price.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# The file is read and displayed above with 26 columns and 205 rows

# %%
df.shape
# Out:
# (205, 26)

# %%
df1 = df.select_dtypes('number')
df1
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0         1          3       88.6      168.8      64.1       48.8        2548
# 1         2          3       88.6      168.8      64.1       48.8        2548
# 2         3          1       94.5      171.2      65.5       52.4        2823
# 3         4          2       99.8      176.6      66.2       54.3        2337
# 4         5          2       99.4      176.6      66.4       54.3        2824
# ..      ...        ...        ...        ...       ...        ...         ...
# 200     201         -1      109.1      188.8      68.9       55.5        2952
# 201     202         -1      109.1      188.8      68.8       55.5        3049
# 202     203         -1      109.1      188.8      68.9       55.5        3012
# 203     204         -1      109.1      188.8      68.9       55.5        3217
# 204     205         -1      109.1      188.8      68.9       55.5        3062
#
# ...

# %% [markdown]
# The columns with only numbers (integers) are taken here or columns are sorted with numbers

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# No data is empty or null in the given data (df and df1)

# %%
count = df["symboling"].value_counts()
print(count)
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
sns.countplot(x="symboling",data=df)
plt.show()

# %%
count = df["CarName"].value_counts()
print(count)
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
count = df["fueltype"].value_counts()
print(count)
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
sns.countplot(x="fueltype",data=df)
plt.show()

# %% [markdown]
# More than 175 cars are having gas as fuel and less than 25 car diesel

# %%
count = df["aspiration"].value_counts()
print(count)
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
sns.countplot(x='aspiration',data=df)
plt.show()

# %%
count = df["doornumber"].value_counts()
print(count)
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
sns.countplot(x="doornumber",data=df)
plt.show()

# %%
count = df["carbody"].value_counts()
(count)
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
sns.countplot(x="carbody",data=df)
plt.show()

# %%
count = df["drivewheel"].value_counts()
print(count)
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
sns.countplot(x="drivewheel",data=df)
plt.show()

# %%
count = df["enginelocation"].value_counts()
print(count)
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
sns.countplot(x="enginelocation",data=df)
plt.show()

# %%
count = df["enginesize"].value_counts()
print(count)
# Out:
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 152     6
# 181     6
# 146     6
# 121     6
# 156     5
# 136     5
# 91      5
# 183     4
# 130     4
# 171     3
# 70      3
# 194     3
# 209     3
# 164     3
# 258     2
# 140     2
# 134     2
# 234     2
# 132     2
# 131     2
# 173     1
# 203     1
# 161     1
# 80      1
# 151     1
# 103     1
# 304     1
# 308     1
# 326     1
# 119     1
# 111     1
# 79      1
# 61      1
# 145     1
# Name: enginesize, dtype: int64

# %%
sns.jointplot(x="enginesize", y="stroke", data=df, kind="hex")
plt.show()

# %%
count = df["fuelsystem"].value_counts()
print(count)
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
sns.countplot(x="fuelsystem",data=df)
plt.show()

# %%
count = df["horsepower"].value_counts()
print(count)
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 160     6
# 101     6
# 62      6
# 88      6
# 145     5
# 76      5
# 97      5
# 84      5
# 90      5
# 82      5
# 102     5
# 92      4
# 111     4
# 123     4
# 86      4
# 207     3
# 73      3
# 182     3
# 121     3
# 85      3
# 152     3
# 176     2
# 94      2
# 56      2
# 112     2
# 161     2
# 184     2
# 155     2
# 156     2
# 52      2
# 100     2
# 162     2
# 140     1
# 115     1
# 134     1
# 78      1
# 142     1
# 288     1
# 143     1
# 48      1
# 200     1
# 58      1
# 55      1
# 60      1
# 175     1
# 154     1
# 72      1
# 120     1
# 64      1
# 135     1
# 262     1
# 106     1
# Name: horsepower, dtype: int64

# %%
sns.jointplot(x="horsepower",y="peakrpm",data=df,kind='hex')
plt.show()

# %%
count = df["citympg"].value_counts()
print(count)
# Out:
# 31    28
# 19    27
# 24    22
# 27    14
# 17    13
# 26    12
# 23    12
# 21     8
# 25     8
# 30     8
# 38     7
# 28     7
# 16     6
# 37     6
# 22     4
# 29     3
# 15     3
# 20     3
# 18     3
# 14     2
# 34     1
# 35     1
# 32     1
# 36     1
# 45     1
# 13     1
# 49     1
# 47     1
# 33     1
# Name: citympg, dtype: int64

# %%
sns.jointplot(x="citympg",y="highwaympg",data=df,kind="hex")
plt.show()

# %%
count=df["price"].value_counts()
print(count)
# Out:
# 8921.0     2
# 9279.0     2
# 7898.0     2
# 8916.5     2
# 7775.0     2
#           ..
# 45400.0    1
# 16503.0    1
# 5389.0     1
# 6189.0     1
# 22625.0    1
# Name: price, Length: 189, dtype: int64

# %%
sns.jointplot(x="price",y="car_ID",data=df,kind="hex",color="red")
plt.show()

# %%
count = df["peakrpm"].value_counts()
print(count)
# Out:
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 4500     7
# 5800     7
# 5250     7
# 5100     5
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5900     3
# 4250     3
# 4400     3
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: peakrpm, dtype: int64

# %%
sns.jointplot(x="boreratio",y="peakrpm",data=df,kind="hex",color="black")
plt.show()

# %%
df1=df.drop("car_ID",axis=1)
df1
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
df1.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
plt.figure(figsize=(17,17))
sns.heatmap(df1.corr(),annot = True, cmap="RdBu")
plt.show()
